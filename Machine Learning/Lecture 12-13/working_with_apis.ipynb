# %% [markdown]
# #### TMDB -- The Movies DB
# -  Create Account
# - Go to profile
# - Generate key
# - select api
# - copy curl and use

# %%
import pandas as pd
import requests


url = "https://api.themoviedb.org/3/trending/all/day?api_key=e3d7e3df77aaeb5828727fe6483d8ceflanguage=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlM2Q3ZTNkZjc3YWFlYjU4Mjg3MjdmZTY0ODNkOGNlZiIsIm5iZiI6MTc3NzU0NTgzOC41NDcwMDAyLCJzdWIiOiI2OWYzMzI2ZWMxNmE0OTYwZWJkNTIwYWQiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.9WMwJ9AAmP8OmFvvzzFAUFpTdHOVkJvGcI82YSgL1g0"
}

# %%
response = requests.get(url, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
# ...

# %%
pd.DataFrame(response.json()['results'])

# %% [markdown]
# ### Page

# %%
import pandas as pd
import requests
data = pd.DataFrame()
for i in range(1,11):
  url = f"https://api.themoviedb.org/3/trending/movie/day?api_key=e3d7e3df77aaeb5828727fe6483d8ceflanguage=en-US&page={i}".format(i)

  headers = {
      "accept": "application/json",
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlM2Q3ZTNkZjc3YWFlYjU4Mjg3MjdmZTY0ODNkOGNlZiIsIm5iZiI6MTc3NzU0NTgzOC41NDcwMDAyLCJzdWIiOiI2OWYzMzI2ZWMxNmE0OTYwZWJkNTIwYWQiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.9WMwJ9AAmP8OmFvvzzFAUFpTdHOVkJvGcI82YSgL1g0"
  }

  response = requests.get(url, headers=headers)
  df = pd.DataFrame(response.json()['results'])
  df = df[['id','title', 'original_title','overview','original_language','popularity','release_date','vote_average',
       'vote_count',]]
  data = pd.concat([data, df], ignore_index=False)

data
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\OneDrive - Motherson Group\Generative AI\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
# ...

# %%
data.to_csv("Trending_Movies.csv", index=False)
