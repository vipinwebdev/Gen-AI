# %% [markdown]
# ### JSON

# %%
import pandas as pd

pd.read_json("https://jsonplaceholder.typicode.com/users")
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
pd.read_json("../ML_Datasets/iris.json")
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### SQL

# %%
records = [
    {"id": 1, "name": "Kabul", "countryCode": "AFG", "district": "Kabol", "population": 1780000},
    {"id": 2, "name": "Qandahar", "countryCode": "AFG", "district": "Qandahar", "population": 237500},
    {"id": 3, "name": "Herat", "countryCode": "AFG", "district": "Herat", "population": 186800},
    {"id": 4, "name": "Mazar-e-Sharif", "countryCode": "AFG", "district": "Balkh", "population": 127800},

    {"id": 5, "name": "Amsterdam", "countryCode": "NLD", "district": "Noord-Holland", "population": 731200},
    {"id": 6, "name": "Rotterdam", "countryCode": "NLD", "district": "Zuid-Holland", "population": 593321},
    {"id": 7, "name": "Utrecht", "countryCode": "NLD", "district": "Utrecht", "population": 234323},
    {"id": 8, "name": "Eindhoven", "countryCode": "NLD", "district": "Noord-Brabant", "population": 201843},

    {"id": 9, "name": "Mumbai", "countryCode": "IND", "district": "Maharashtra", "population": 12442373},
    {"id": 10, "name": "Delhi", "countryCode": "IND", "district": "Delhi", "population": 11034555},
    {"id": 11, "name": "Bangalore", "countryCode": "IND", "district": "Karnataka", "population": 8443675},
    {"id": 12, "name": "Hyderabad", "countryCode": "IND", "district": "Telangana", "population": 6809970},
    {"id": 13, "name": "Chennai", "countryCode": "IND", "district": "Tamil Nadu", "population": 7090000},
    {"id": 14, "name": "Kolkata", "countryCode": "IND", "district": "West Bengal", "population": 4486679},

    {"id": 15, "name": "New York", "countryCode": "USA", "district": "New York", "population": 8419600},
    {"id": 16, "name": "Los Angeles", "countryCode": "USA", "district": "California", "population": 3980400},
    {"id": 17, "name": "Chicago", "countryCode": "USA", "district": "Illinois", "population": 2716000},
    {"id": 18, "name": "Houston", "countryCode": "USA", "district": "Texas", "population": 2328000},
    {"id": 19, "name": "Phoenix", "countryCode": "USA", "district": "Arizona", "population": 1690000},

    {"id": 20, "name": "London", "countryCode": "GBR", "district": "England", "population": 8982000},
    {"id": 21, "name": "Manchester", "countryCode": "GBR", "district": "England", "population": 553230},
    {"id": 22, "name": "Birmingham", "countryCode": "GBR", "district": "England", "population": 1141816},

    {"id": 23, "name": "Sydney", "countryCode": "AUS", "district": "NSW", "population": 5312163},
    {"id": 24, "name": "Melbourne", "countryCode": "AUS", "district": "Victoria", "population": 5078193},
    {"id": 25, "name": "Brisbane", "countryCode": "AUS", "district": "Queensland", "population": 2514184},

    {"id": 26, "name": "Paris", "countryCode": "FRA", "district": "Ile-de-France", "population": 2148000},
    {"id": 27, "name": "Lyon", "countryCode": "FRA", "district": "Auvergne-Rhone-Alpes", "population": 515695},
    {"id": 28, "name": "Marseille", "countryCode": "FRA", "district": "Provence", "population": 861635},

    {"id": 29, "name": "Berlin", "countryCode": "DEU", "district": "Berlin", "population": 3645000},
    {"id": 30, "name": "Munich", "countryCode": "DEU", "district": "Bavaria", "population": 1472000},
    {"id": 31, "name": "Hamburg", "countryCode": "DEU", "district": "Hamburg", "population": 1841000},

    {"id": 32, "name": "Tokyo", "countryCode": "JPN", "district": "Tokyo", "population": 13960000},
    {"id": 33, "name": "Osaka", "countryCode": "JPN", "district": "Osaka", "population": 2691000},
    {"id": 34, "name": "Nagoya", "countryCode": "JPN", "district": "Aichi", "population": 2296000},

    {"id": 35, "name": "Beijing", "countryCode": "CHN", "district": "Beijing", "population": 21540000},
    {"id": 36, "name": "Shanghai", "countryCode": "CHN", "district": "Shanghai", "population": 24240000},
    {"id": 37, "name": "Shenzhen", "countryCode": "CHN", "district": "Guangdong", "population": 12530000},

    {"id": 38, "name": "Moscow", "countryCode": "RUS", "district": "Moscow", "population": 11920000},
    {"id": 39, "name": "Saint Petersburg", "countryCode": "RUS", "district": "Northwestern", "population": 5384000},

    {"id": 40, "name": "Toronto", "countryCode": "CAN", "district": "Ontario", "population": 2930000},
    {"id": 41, "name": "Vancouver", "countryCode": "CAN", "district": "British Columbia", "population": 675218},
    {"id": 42, "name": "Montreal", "countryCode": "CAN", "district": "Quebec", "population": 1780000},

    {"id": 43, "name": "Dubai", "countryCode": "ARE", "district": "Dubai", "population": 3331000},
    {"id": 44, "name": "Abu Dhabi", "countryCode": "ARE", "district": "Abu Dhabi", "population": 1450000},

    {"id": 45, "name": "Cape Town", "countryCode": "ZAF", "district": "Western Cape", "population": 4337000},
    {"id": 46, "name": "Johannesburg", "countryCode": "ZAF", "district": "Gauteng", "population": 957441},

    {"id": 47, "name": "Rome", "countryCode": "ITA", "district": "Lazio", "population": 2873000},
    {"id": 48, "name": "Milan", "countryCode": "ITA", "district": "Lombardy", "population": 1378000},

    {"id": 49, "name": "Madrid", "countryCode": "ESP", "district": "Madrid", "population": 3223000},
    {"id": 50, "name": "Barcelona", "countryCode": "ESP", "district": "Catalonia", "population": 1620000},

    {"id": 51, "name": "Seoul", "countryCode": "KOR", "district": "Seoul", "population": 9776000},
    {"id": 52, "name": "Busan", "countryCode": "KOR", "district": "Busan", "population": 3449000},

    {"id": 53, "name": "Bangkok", "countryCode": "THA", "district": "Bangkok", "population": 10539000},
    {"id": 54, "name": "Phuket", "countryCode": "THA", "district": "Phuket", "population": 416000},

    {"id": 55, "name": "Jakarta", "countryCode": "IDN", "district": "Jakarta", "population": 10770487},
    {"id": 56, "name": "Surabaya", "countryCode": "IDN", "district": "East Java", "population": 2874000},

    {"id": 57, "name": "Mexico City", "countryCode": "MEX", "district": "Mexico City", "population": 9209944},
    {"id": 58, "name": "Guadalajara", "countryCode": "MEX", "district": "Jalisco", "population": 1495182},

    {"id": 59, "name": "Sao Paulo", "countryCode": "BRA", "district": "Sao Paulo", "population": 12330000},
    {"id": 60, "name": "Rio de Janeiro", "countryCode": "BRA", "district": "Rio", "population": 6748000},

    {"id": 61, "name": "Lagos", "countryCode": "NGA", "district": "Lagos", "population": 14862000},
    {"id": 62, "name": "Abuja", "countryCode": "NGA", "district": "FCT", "population": 1235880},

    {"id": 63, "name": "Karachi", "countryCode": "PAK", "district": "Sindh", "population": 14910352},
    {"id": 64, "name": "Lahore", "countryCode": "PAK", "district": "Punjab", "population": 11126285},

    {"id": 65, "name": "Dhaka", "countryCode": "BGD", "district": "Dhaka", "population": 8906039},
    {"id": 66, "name": "Chittagong", "countryCode": "BGD", "district": "Chattogram", "population": 2581643},

    {"id": 67, "name": "Tehran", "countryCode": "IRN", "district": "Tehran", "population": 8847000},
    {"id": 68, "name": "Mashhad", "countryCode": "IRN", "district": "Razavi", "population": 3001184},

    {"id": 69, "name": "Istanbul", "countryCode": "TUR", "district": "Istanbul", "population": 15460000},
    {"id": 70, "name": "Ankara", "countryCode": "TUR", "district": "Ankara", "population": 5663000},

    {"id": 71, "name": "Athens", "countryCode": "GRC", "district": "Attica", "population": 664046},
    {"id": 72, "name": "Thessaloniki", "countryCode": "GRC", "district": "Central Macedonia", "population": 315196},

    {"id": 73, "name": "Cairo", "countryCode": "EGY", "district": "Cairo", "population": 9900000},
    {"id": 74, "name": "Alexandria", "countryCode": "EGY", "district": "Alexandria", "population": 5200000},

    {"id": 75, "name": "Hanoi", "countryCode": "VNM", "district": "Hanoi", "population": 8000000},
    {"id": 76, "name": "Ho Chi Minh City", "countryCode": "VNM", "district": "HCMC", "population": 9000000},

    {"id": 77, "name": "Manila", "countryCode": "PHL", "district": "Metro Manila", "population": 1780148},
    {"id": 78, "name": "Cebu", "countryCode": "PHL", "district": "Cebu", "population": 964169},

    {"id": 79, "name": "Lima", "countryCode": "PER", "district": "Lima", "population": 9674755},
    {"id": 80, "name": "Cusco", "countryCode": "PER", "district": "Cusco", "population": 428450},

    {"id": 81, "name": "Buenos Aires", "countryCode": "ARG", "district": "Buenos Aires", "population": 3075646},
    {"id": 82, "name": "Cordoba", "countryCode": "ARG", "district": "Cordoba", "population": 1391000},

    {"id": 83, "name": "Santiago", "countryCode": "CHL", "district": "Santiago", "population": 5743719},
    {"id": 84, "name": "Valparaiso", "countryCode": "CHL", "district": "Valparaiso", "population": 967000},

    {"id": 85, "name": "Auckland", "countryCode": "NZL", "district": "Auckland", "population": 1657000},
    {"id": 86, "name": "Wellington", "countryCode": "NZL", "district": "Wellington", "population": 215100},

    {"id": 87, "name": "Helsinki", "countryCode": "FIN", "district": "Uusimaa", "population": 656611},
    {"id": 88, "name": "Oslo", "countryCode": "NOR", "district": "Oslo", "population": 681067},

    {"id": 89, "name": "Stockholm", "countryCode": "SWE", "district": "Stockholm", "population": 975551},
    {"id": 90, "name": "Copenhagen", "countryCode": "DNK", "district": "Capital", "population": 794128},

    {"id": 91, "name": "Zurich", "countryCode": "CHE", "district": "Zurich", "population": 402762},
    {"id": 92, "name": "Geneva", "countryCode": "CHE", "district": "Geneva", "population": 201818},

    {"id": 93, "name": "Brussels", "countryCode": "BEL", "district": "Brussels", "population": 185103},
    {"id": 94, "name": "Antwerp", "countryCode": "BEL", "district": "Flanders", "population": 529247},

    {"id": 95, "name": "Vienna", "countryCode": "AUT", "district": "Vienna", "population": 1897000},
    {"id": 96, "name": "Salzburg", "countryCode": "AUT", "district": "Salzburg", "population": 155416},

    {"id": 97, "name": "Prague", "countryCode": "CZE", "district": "Prague", "population": 1309000},
    {"id": 98, "name": "Brno", "countryCode": "CZE", "district": "South Moravia", "population": 382405},

    {"id": 99, "name": "Budapest", "countryCode": "HUN", "district": "Budapest", "population": 1756000},
    {"id": 100, "name": "Debrecen", "countryCode": "HUN", "district": "Hajdu-Bihar", "population": 201432}
];

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = client["world_cities"]
cities = db["cities"]
cities.insert_many(records)

# %%
# # Fetch all records
for doc in cities.find({}, {"_id": 0, "id": 1, "name": 1, "countryCode": 1}):
    print(doc)

# %%
data = list(cities.find({}, {"_id": 0}))

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    id            name countryCode       district  population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %% [markdown]
# ### sql connector
#
# ```python
#
# import mysql.connector
#
# data = mysql.connector.connect(host = '',user='', password='',database='')
#
# pd.read_sql("query", data)
#
# ```

# %% [markdown]
# ##### data filtering conditionally

# %%
pd.DataFrame(list(cities.find({"countryCode": "IND"}, {"_id": 0})))
# Out:
#    id       name countryCode     district  population
# 0   9     Mumbai         IND  Maharashtra    12442373
# 1  10      Delhi         IND        Delhi    11034555
# 2  11  Bangalore         IND    Karnataka     8443675
# 3  12  Hyderabad         IND    Telangana     6809970
# 4  13    Chennai         IND   Tamil Nadu     7090000
# 5  14    Kolkata         IND  West Bengal     4486679

# %%
pd.DataFrame(list(cities.find({"population": {"$gt": 500000}}, {"_id": 0})))
# Out:
#     id        name countryCode       district  population
# 0    1       Kabul         AFG          Kabol     1780000
# 1    5   Amsterdam         NLD  Noord-Holland      731200
# 2    6   Rotterdam         NLD   Zuid-Holland      593321
# 3    9      Mumbai         IND    Maharashtra    12442373
# 4   10       Delhi         IND          Delhi    11034555
# ..  ..         ...         ...            ...         ...
# 80  90  Copenhagen         DNK        Capital      794128
# 81  94     Antwerp         BEL       Flanders      529247
# 82  95      Vienna         AUT         Vienna     1897000
# 83  97      Prague         CZE         Prague     1309000
# 84  99    Budapest         HUN       Budapest     1756000
#
# [85 rows x 5 columns]

# %%
pd.DataFrame(list(cities.find({"countryCode": "NLD", "population": {"$gt": 500000}}, {"_id": 0})))
# Out:
#    id       name countryCode       district  population
# 0   5  Amsterdam         NLD  Noord-Holland      731200
# 1   6  Rotterdam         NLD   Zuid-Holland      593321
